# %%
import parmed as pmd

# %%
struct=pmd.load_file('asyn_equil_init.pdb')

# %%
struct
# Out:
# <Structure 140 atoms; 140 residues; 0 bonds; PBC (orthogonal); NOT parametrized>

# %%
for a in struct.atoms:
    print(a.name, a.residue, a.mass)
    a.mass = 50
# Out:
# CA <Residue MET[1]; chain=A> 12.0107
# CA <Residue ASP[2]; chain=A> 12.0107
# CA <Residue VAL[3]; chain=A> 12.0107
# CA <Residue PHE[4]; chain=A> 12.0107
# CA <Residue MET[5]; chain=A> 12.0107
# CA <Residue LYS[6]; chain=A> 12.0107
# CA <Residue GLY[7]; chain=A> 12.0107
# CA <Residue LEU[8]; chain=A> 12.0107
# CA <Residue SER[9]; chain=A> 12.0107
# CA <Residue LYS[10]; chain=A> 12.0107
# CA <Residue ALA[11]; chain=A> 12.0107
# CA <Residue LYS[12]; chain=A> 12.0107
# CA <Residue GLU[13]; chain=A> 12.0107
# CA <Residue GLY[14]; chain=A> 12.0107
# CA <Residue VAL[15]; chain=A> 12.0107
# CA <Residue VAL[16]; chain=A> 12.0107
# CA <Residue ALA[17]; chain=A> 12.0107
# CA <Residue ALA[18]; chain=A> 12.0107
# CA <Residue ALA[19]; chain=A> 12.0107
# CA <Residue GLU[20]; chain=A> 12.0107
# CA <Residue LYS[21]; chain=A> 12.0107
# CA <Residue THR[22]; chain=A> 12.0107
# CA <Residue LYS[23]; chain=A> 12.0107
# CA <Residue GLN[24]; chain=A> 12.0107
# CA <Residue GLY[25]; chain=A> 12.0107
# ...

# %%
for a in struct.atoms:
    print(a.name, a.residue, a.mass, a.charge)
# Out:
# CA <Residue MET[1]; chain=A> 50 0.0
# CA <Residue ASP[2]; chain=A> 50 0.0
# CA <Residue VAL[3]; chain=A> 50 0.0
# CA <Residue PHE[4]; chain=A> 50 0.0
# CA <Residue MET[5]; chain=A> 50 0.0
# CA <Residue LYS[6]; chain=A> 50 0.0
# CA <Residue GLY[7]; chain=A> 50 0.0
# CA <Residue LEU[8]; chain=A> 50 0.0
# CA <Residue SER[9]; chain=A> 50 0.0
# CA <Residue LYS[10]; chain=A> 50 0.0
# CA <Residue ALA[11]; chain=A> 50 0.0
# CA <Residue LYS[12]; chain=A> 50 0.0
# CA <Residue GLU[13]; chain=A> 50 0.0
# CA <Residue GLY[14]; chain=A> 50 0.0
# CA <Residue VAL[15]; chain=A> 50 0.0
# CA <Residue VAL[16]; chain=A> 50 0.0
# CA <Residue ALA[17]; chain=A> 50 0.0
# CA <Residue ALA[18]; chain=A> 50 0.0
# CA <Residue ALA[19]; chain=A> 50 0.0
# CA <Residue GLU[20]; chain=A> 50 0.0
# CA <Residue LYS[21]; chain=A> 50 0.0
# CA <Residue THR[22]; chain=A> 50 0.0
# CA <Residue LYS[23]; chain=A> 50 0.0
# CA <Residue GLN[24]; chain=A> 50 0.0
# CA <Residue GLY[25]; chain=A> 50 0.0
# ...

# %%
struct.save('test.psf')
